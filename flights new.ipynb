# %%
pip install seaborn
# Out:
# ...
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import pandas as pd

# %%
mn=pd.read_csv("C:\\Users\PRABHURAJ K B\\OneDrive\\Desktop\\flight price (1).csv")
mn
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      24-03-2019  Banglore   New Delhi    22:20
# 1        Air India      01-05-2019   Kolkata    Banglore     5:50
# 2      Jet Airways      09-06-2019     Delhi      Cochin     9:25
# 3           IndiGo      12-05-2019   Kolkata    Banglore    18:05
# 4           IndiGo      01-03-2019  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia      09-04-2019   Kolkata    Banglore    19:55
# 10679    Air India      27-04-2019   Kolkata    Banglore    20:45
# 10680  Jet Airways      27-04-2019  Banglore       Delhi     8:20
# 10681      Vistara      01-03-2019  Banglore   New Delhi    11:30
# 10682    Air India      09-05-2019     Delhi      Cochin    10:55
#
#            Arrival_Time Duration Total_Stops Additional_Info  Price
# 0                   NaN   2h 50m    non-stop         No info   3897
# ...

# %%
mn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Dep_Time         10683 non-null  object
#  5   Arrival_Time     10682 non-null  object
#  6   Duration         10683 non-null  object
#  7   Total_Stops      10682 non-null  object
#  8   Additional_Info  10683 non-null  object
#  9   Price            10683 non-null  int64
# dtypes: int64(1), object(9)
# memory usage: 834.7+ KB

# %%
mn.shape
# Out:
# (10683, 10)

# %%
mn.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
mn.size
# Out:
# 106830

# %%
mn.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Dep_Time',
#        'Arrival_Time', 'Duration', 'Total_Stops', 'Additional_Info', 'Price'],
#       dtype='object')

# %%
mn.head()
# Out:
#        Airline Date_of_Journey    Source Destination Dep_Time  \
# 0       IndiGo      24-03-2019  Banglore   New Delhi    22:20
# 1    Air India      01-05-2019   Kolkata    Banglore     5:50
# 2  Jet Airways      09-06-2019     Delhi      Cochin     9:25
# 3       IndiGo      12-05-2019   Kolkata    Banglore    18:05
# 4       IndiGo      01-03-2019  Banglore   New Delhi    16:50
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price
# 0               NaN   2h 50m    non-stop         No info   3897
# 1             13:15   7h 25m     2 stops         No info   7662
# 2  10-06-2023 04:25      19h     2 stops         No info  13882
# 3             23:30   5h 25m      1 stop         No info   6218
# 4             21:35   4h 45m      1 stop         No info  13302

# %%
mn.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Dep_Time           0
# Arrival_Time       1
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
 nb Date_of_Journey']=pd.to_datetime
mn
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi    22:20
# 1        Air India      2019-01-05   Kolkata    Banglore     5:50
# 2      Jet Airways      2019-09-06     Delhi      Cochin     9:25
# 3           IndiGo      2019-12-05   Kolkata    Banglore    18:05
# 4           IndiGo      2019-01-03  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia      2019-09-04   Kolkata    Banglore    19:55
# 10679    Air India      2019-04-27   Kolkata    Banglore    20:45
# 10680  Jet Airways      2019-04-27  Banglore       Delhi     8:20
# 10681      Vistara      2019-01-03  Banglore   New Delhi    11:30
# 10682    Air India      2019-09-05     Delhi      Cochin    10:55
#
#            Arrival_Time Duration Total_Stops Additional_Info  Price
# 0                   NaN   2h 50m    non-stop         No info   3897
# ...

# %%
mn["Arrival_Time"].unique()
# Out:
# array([nan, '13:15', '10-06-2023 04:25', ..., '10-03-2023 06:50',
#        '19-03-2023 00:05', '13-03-2023 21:20'], dtype=object)

# %%
mn["Total_Stops"].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
mn["Total_Stops"] = mn["Total_Stops"].fillna("zero stop")
mn
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi    22:20
# 1        Air India      2019-01-05   Kolkata    Banglore     5:50
# 2      Jet Airways      2019-09-06     Delhi      Cochin     9:25
# 3           IndiGo      2019-12-05   Kolkata    Banglore    18:05
# 4           IndiGo      2019-01-03  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia      2019-09-04   Kolkata    Banglore    19:55
# 10679    Air India      2019-04-27   Kolkata    Banglore    20:45
# 10680  Jet Airways      2019-04-27  Banglore       Delhi     8:20
# 10681      Vistara      2019-01-03  Banglore   New Delhi    11:30
# 10682    Air India      2019-09-05     Delhi      Cochin    10:55
#
#            Arrival_Time Duration Total_Stops Additional_Info  Price
# 0                   NaN   2h 50m    non-stop         No info   3897
# ...

# %%
mn.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Dep_Time           0
# Arrival_Time       1
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
mn["Date_of_Journey"] = pd.to_datetime(mn["Date_of_Journey"])
mn
# Out:
#            Airline Date_of_Journey    Source Destination Dep_Time  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi    22:20
# 1        Air India      2019-01-05   Kolkata    Banglore     5:50
# 2      Jet Airways      2019-09-06     Delhi      Cochin     9:25
# 3           IndiGo      2019-12-05   Kolkata    Banglore    18:05
# 4           IndiGo      2019-01-03  Banglore   New Delhi    16:50
# ...            ...             ...       ...         ...      ...
# 10678     Air Asia      2019-09-04   Kolkata    Banglore    19:55
# 10679    Air India      2019-04-27   Kolkata    Banglore    20:45
# 10680  Jet Airways      2019-04-27  Banglore       Delhi     8:20
# 10681      Vistara      2019-01-03  Banglore   New Delhi    11:30
# 10682    Air India      2019-09-05     Delhi      Cochin    10:55
#
#            Arrival_Time Duration Total_Stops Additional_Info  Price
# 0                   NaN   2h 50m    non-stop         No info   3897
# ...

# %%
mn["Dep_Time"] = pd.to_datetime(mn["Dep_Time"])
mn
# Out:
#            Airline Date_of_Journey    Source Destination            Dep_Time  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi 2023-09-05 22:20:00
# 1        Air India      2019-01-05   Kolkata    Banglore 2023-09-05 05:50:00
# 2      Jet Airways      2019-09-06     Delhi      Cochin 2023-09-05 09:25:00
# 3           IndiGo      2019-12-05   Kolkata    Banglore 2023-09-05 18:05:00
# 4           IndiGo      2019-01-03  Banglore   New Delhi 2023-09-05 16:50:00
# ...            ...             ...       ...         ...                 ...
# 10678     Air Asia      2019-09-04   Kolkata    Banglore 2023-09-05 19:55:00
# 10679    Air India      2019-04-27   Kolkata    Banglore 2023-09-05 20:45:00
# 10680  Jet Airways      2019-04-27  Banglore       Delhi 2023-09-05 08:20:00
# 10681      Vistara      2019-01-03  Banglore   New Delhi 2023-09-05 11:30:00
# 10682    Air India      2019-09-05     Delhi      Cochin 2023-09-05 10:55:00
#
# ...

# %%
mn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  datetime64[ns]
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Dep_Time         10683 non-null  datetime64[ns]
#  5   Arrival_Time     10682 non-null  object
#  6   Duration         10683 non-null  object
#  7   Total_Stops      10683 non-null  object
#  8   Additional_Info  10683 non-null  object
#  9   Price            10683 non-null  int64
# dtypes: datetime64[ns](2), int64(1), object(7)
# memory usage: 834.7+ KB

# %%
import matplotlib.pyplot as plt
plt.bar(mn["Airline"] ,mn["Price"],color = ["red","pink","blue","green","purple","yellow","black","red"])
plt.ylabel("Price",fontsize = 10)
plt.xticks(rotation = 90)
plt.title("Bar graph",fontsize = 20)
plt.xlabel("Airline name",fontsize = 10)
# Out:
# Text(0.5, 0, 'Airline name')
